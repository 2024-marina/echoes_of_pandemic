# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
unempl = pd.read_csv('../data/unemployment_rate.csv', nrows = 266)

# %%
unempl = unempl.drop(columns = ['Series Name', 'Series Code', 'Country Code'])

# %%
unempl =  unempl.rename(columns = {'Country Name' : 'Country'})

# %%
unempl.columns
# Out:
# Index(['Country', '2000 [YR2000]', '2001 [YR2001]', '2002 [YR2002]',
#        '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]',
#        '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]',
#        '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]',
#        '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]',
#        '2019 [YR2019]', '2020 [YR2020]', '2021 [YR2021]', '2022 [YR2022]',
#        '2023 [YR2023]'],
#       dtype='object')

# %%
unempl.columns = unempl.columns.str.replace(r'\[YR\d+\]', '', regex = True)

# %%
unempl['Country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Channel Islands', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'Ecuador', 'Egypt, Arab Rep.', 'El Salvador',
#        'Equatorial Guinea', 'Eritrea', 'Estonia', 'Eswatini', 'Ethiopia',
#        'Faroe Islands', 'Fiji', 'Finland', 'France', 'French Polynesia',
#        'Gabon', 'Gambia, The', 'Georgia', 'Germany', 'Ghana', 'Gibraltar',
#        'Greece', 'Greenland', 'Grenada', 'Guam', 'Guatemala', 'Guinea',
#        'Guinea-Bissau', 'Guyana', 'Haiti', 'Honduras',
#        'Hong Kong SAR, China', 'Hungary', 'Iceland', 'India', 'Indonesia',
#        'Iran, Islamic Rep.', 'Iraq', 'Ireland', 'Isle of Man', 'Israel',
#        'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya',
#        'Kiribati', "Korea, Dem. People's Rep.", 'Korea, Rep.', 'Kosovo',
#        'Kuwait', 'Kyrgyz Republic', 'Lao PDR', 'Latvia', 'Lebanon',
#        'Lesotho', 'Liberia', 'Libya', 'Liechtenstein', 'Lithuania',
#        'Luxembourg', 'Macao SAR, China', 'Madagascar', 'Malawi',
#        'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marshall Islands',
#        'Mauritania', 'Mauritius', 'Mexico', 'Micronesia, Fed. Sts.',
#        'Moldova', 'Monaco', 'Mongolia', 'Montenegro', 'Morocco',
#        'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal',
#        'Netherlands', 'New Caledonia', 'New Zealand', 'Nicaragua',
#        'Niger', 'Nigeria', 'North Macedonia', 'Northern Mariana Islands',
#        'Norway', 'Oman', 'Pakistan', 'Palau', 'Panama',
#        'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland',
#        'Portugal', 'Puerto Rico', 'Qatar', 'Romania',
#        'Russian Federation', 'Rwanda', 'Samoa', 'San Marino',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia',
#        'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovak Republic', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South Sudan',
#        'Spain', 'Sri Lanka', 'St. Kitts and Nevis', 'St. Lucia',
#        'St. Martin (French part)', 'St. Vincent and the Grenadines',
#        'Sudan', 'Suriname', 'Sweden', 'Switzerland',
#        'Syrian Arab Republic', 'Tajikistan', 'Tanzania', 'Thailand',
#        'Timor-Leste', 'Togo', 'Tonga', 'Trinidad and Tobago', 'Tunisia',
#        'Turkiye', 'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu',
#        'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Venezuela, RB', 'Viet Nam', 'Virgin Islands (U.S.)',
#        'West Bank and Gaza', 'Yemen, Rep.', 'Zambia', 'Zimbabwe',
#        'Africa Eastern and Southern', 'Africa Western and Central',
#        'Arab World', 'Caribbean small states',
#        'Central Europe and the Baltics', 'Early-demographic dividend',
#        'East Asia & Pacific',
#        'East Asia & Pacific (excluding high income)',
#        'East Asia & Pacific (IDA & IBRD countries)', 'Euro area',
#        'Europe & Central Asia',
#        'Europe & Central Asia (excluding high income)',
#        'Europe & Central Asia (IDA & IBRD countries)', 'European Union',
#        'Fragile and conflict affected situations',
#        'Heavily indebted poor countries (HIPC)', 'High income',
#        'IBRD only', 'IDA & IBRD total', 'IDA blend', 'IDA only',
#        'IDA total', 'Late-demographic dividend',
#        'Latin America & Caribbean',
#        'Latin America & Caribbean (excluding high income)',
#        'Latin America & the Caribbean (IDA & IBRD countries)',
#        'Least developed countries: UN classification',
#        'Low & middle income', 'Low income', 'Lower middle income',
#        'Middle East & North Africa',
#        'Middle East & North Africa (excluding high income)',
#        'Middle East & North Africa (IDA & IBRD countries)',
#        'Middle income', 'North America', 'Not classified', 'OECD members',
#        'Other small states', 'Pacific island small states',
#        'Post-demographic dividend', 'Pre-demographic dividend',
#        'Small states', 'South Asia', 'South Asia (IDA & IBRD)',
#        'Sub-Saharan Africa', 'Sub-Saharan Africa (excluding high income)',
#        'Sub-Saharan Africa (IDA & IBRD countries)', 'Upper middle income',
#        'World'], dtype=object)

# %%
delete = ['Africa Eastern and Southern', 'Africa Western and Central', 'Arab World', 'Caribbean small states', 'Central Europe and the Baltics', 'Early-demographic dividend', 'East Asia & Pacific', 'East Asia & Pacific (excluding high income)', 'East Asia & Pacific (IDA & IBRD countries)', 'Euro area', 'Europe & Central Asia', 'Europe & Central Asia (excluding high income)', 'Europe & Central Asia (IDA & IBRD countries)', 'European Union', 'Fragile and conflict affected situations', 'Heavily indebted poor countries (HIPC)', 'High income', 'IBRD only', 'IDA & IBRD total', 'IDA blend', 'IDA only', 'IDA total', 'Late-demographic dividend', 'Latin America & Caribbean', 'Latin America & Caribbean (excluding high income)', 'Latin America & the Caribbean (IDA & IBRD countries)', 'Least developed countries: UN classification', 'Low & middle income', 'Low income', 'Lower middle income', 'Middle East & North Africa', 'Middle East & North Africa (excluding high income)', 'Middle East & North Africa (IDA & IBRD countries)', 'Middle income', 'North America', 'Not classified', 'OECD members', 'Other small states', 'Pacific island small states', 'Post-demographic dividend', 'Pre-demographic dividend', 'Small states', 'South Asia', 'South Asia (IDA & IBRD)', 'Sub-Saharan Africa', 'Sub-Saharan Africa (excluding high income)', 'Sub-Saharan Africa (IDA & IBRD countries)', 'Upper middle income']

# %%
cleaned = unempl[~unempl['Country'].isin(delete)]

# %%
cleaned.columns
# Out:
# Index(['Country', '2000 ', '2001 ', '2002 ', '2003 ', '2004 ', '2005 ',
#        '2006 ', '2007 ', '2008 ', '2009 ', '2010 ', '2011 ', '2012 ', '2013 ',
#        '2014 ', '2015 ', '2016 ', '2017 ', '2018 ', '2019 ', '2020 ', '2021 ',
#        '2022 ', '2023 '],
#       dtype='object')

# %%
cleaned.columns = cleaned.columns.str.strip()

# %%
years = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023']

# %%
unpivot = cleaned.melt(id_vars = ['Country'], value_vars = years, var_name = 'Year', value_name = 'Unemployment_rate')

# %%
unpivot
# Out:
#                  Country  Year Unemployment_rate
# 0            Afghanistan  2000             7.955
# 1                Albania  2000            19.023
# 2                Algeria  2000             29.77
# 3         American Samoa  2000                ..
# 4                Andorra  2000                ..
# ...                  ...   ...               ...
# 5227  West Bank and Gaza  2023                ..
# 5228         Yemen, Rep.  2023            17.215
# 5229              Zambia  2023             5.913
# 5230            Zimbabwe  2023             8.759
# 5231               World  2023        4.96143065
#
# [5232 rows x 3 columns]

# %%
##unpivot.to_csv('unempl_world.csv', index = False)

# %%
hdi = pd.read_csv('../data/for_hdi_slide.csv')

# %%
hdi.dtypes
# Out:
# Country     object
# Year         int64
# HDI        float64
# dtype: object

# %%
unpivot.dtypes
# Out:
# Country              object
# Year                 object
# Unemployment_rate    object
# dtype: object

# %%
unpivot['Year'] = pd.to_numeric(unpivot['Year'], errors = 'coerce', downcast = 'integer')

# %%
unpivot['Unemployment_rate'] = pd.to_numeric(unpivot['Unemployment_rate'], errors = 'coerce', downcast = 'integer')

# %%
unpivot.dtypes
# Out:
# Country               object
# Year                   int16
# Unemployment_rate    float64
# dtype: object

# %%
merged_for_corr = pd.merge(unpivot, hdi, on = ['Country', 'Year'])

# %%
def corr(groupped):
    return groupped [['Unemployment_rate', 'HDI']].corr().iloc[0, 1]

# %%
by_year_corr = merged_for_corr.groupby('Year').apply (corr)

# %%
by_year = by_year_corr.to_frame().reset_index()

# %%
by_year = by_year.rename(columns = {0 : 'Correlation'})
by_year
# Out:
#     Year  Correlation
# 0   2000     0.062416
# 1   2001     0.047205
# 2   2002     0.062571
# 3   2003     0.073970
# 4   2004     0.063619
# 5   2005     0.048178
# 6   2006     0.033113
# 7   2007    -0.014008
# 8   2008    -0.017855
# 9   2009     0.112650
# 10  2010     0.134295
# 11  2011     0.118847
# 12  2012     0.135347
# 13  2013     0.143753
# 14  2014     0.123704
# 15  2015     0.084251
# 16  2016     0.055007
# 17  2017     0.003251
# 18  2018    -0.029074
# 19  2019    -0.060138
# 20  2020    -0.039452
# 21  2021    -0.076212
# 22  2022    -0.108168

# %%
##by_year.to_csv('unempl_corr_by_year.csv', index = False)

# %%
by_country_corr = merged_for_corr.groupby('Country').apply(corr)

# %%
by_country = by_country_corr.to_frame().reset_index()

# %%
by_country = by_country.rename(columns = {0 : 'Correlation'})
by_country
# Out:
#            Country  Correlation
# 0      Afghanistan     0.534500
# 1          Albania    -0.648869
# 2          Algeria    -0.835015
# 3          Andorra          NaN
# 4           Angola    -0.063183
# ..             ...          ...
# 183        Vanuatu    -0.628554
# 184  Venezuela, RB    -0.627863
# 185    Yemen, Rep.    -0.511892
# 186         Zambia    -0.863577
# 187       Zimbabwe     0.547221
#
# [188 rows x 2 columns]

# %%
hfi = pd.read_csv('../data/2023-Human-Freedom-Index-Data.csv')

# %%
hfi = hfi.drop(columns = ['iso', 'region'])

# %%
world = hfi.groupby('year')['hf_score'].mean().reset_index()

# %%
world.rename(columns = {'year' : 'Year'}, inplace = True)

# %%
##world.to_csv('hfi_world.csv', index = False)

# %%
world2 = hdi.groupby('Year')['HDI'].mean().reset_index()

# %%
merged = pd.merge(world, world2, on = 'Year')

# %%
merged.rename(columns = {'hf_score' : 'HFI'}, inplace= True)

# %%
merged
# Out:
#     Year       HFI       HDI
# 0   2000  7.143203  0.633663
# 1   2001  7.180894  0.639709
# 2   2002  7.201301  0.643600
# 3   2003  7.208583  0.648239
# 4   2004  7.234692  0.655085
# 5   2005  7.190709  0.660495
# 6   2006  7.204823  0.667500
# 7   2007  7.219220  0.675297
# 8   2008  7.188794  0.680973
# 9   2009  7.167943  0.685135
# 10  2010  7.125882  0.689086
# 11  2011  7.037778  0.693191
# 12  2012  7.023148  0.698351
# 13  2013  7.019877  0.703138
# 14  2014  7.014877  0.707500
# 15  2015  6.993025  0.711011
# 16  2016  7.015000  0.714734
# 17  2017  7.015864  0.718245
# 18  2018  7.026667  0.723175
# 19  2019  6.993818  0.726349
# 20  2020  6.785030  0.720000
# 21  2021  6.749939  0.719630

# %%
merged.dtypes
# Out:
# Year      int64
# HFI     float64
# HDI     float64
# dtype: object

# %%
def corr(groupped):
    return groupped [['HFI', 'HDI']].corr().iloc[0, 1]

# %%
corr = merged[['HFI', 'HDI']].corr().iloc[0, 1]

# %%
corr
# Out:
# -0.7849758533191735

# %%
hfi.rename(columns = {'year' : 'Year', 'countries' : 'Country', 'hf_score' : 'HFI'}, inplace = True)

# %%
merge = pd.merge(hdi, hfi, on = ['Year', 'Country'], how = 'inner')

# %%
merge
# Out:
#             Country  Year   HDI   HFI  hf_rank  hf_quartile  \
# 0           Albania  2000  0.68  7.43     53.0          2.0
# 1           Algeria  2000  0.65  4.79    125.0          4.0
# 2            Angola  2000  0.38   NaN      NaN          NaN
# 3         Argentina  2000  0.78  8.01     41.0          2.0
# 4           Armenia  2000  0.66   NaN      NaN          NaN
# ...             ...   ...   ...   ...      ...          ...
# 3515  Venezuela, RB  2021  0.69  4.22    160.0          4.0
# 3516        Vietnam  2021  0.70  5.51    130.0          4.0
# 3517    Yemen, Rep.  2021  0.46  3.43    164.0          4.0
# 3518         Zambia  2021  0.56  6.21    113.0          3.0
# 3519       Zimbabwe  2021  0.59  4.86    153.0          4.0
#
#       pf_rol_procedural  pf_rol_civil  pf_rol_criminal  pf_rol_vdem  ...  \
# 0                   NaN           NaN              NaN         6.53  ...
# 1                   NaN           NaN              NaN         5.24  ...
# 2                   NaN           NaN              NaN         3.63  ...
# 3                   NaN           NaN              NaN         6.62  ...
# 4                   NaN           NaN              NaN         5.88  ...
# ...                 ...           ...              ...          ...  ...
# 3515                NaN           NaN              NaN         4.29  ...
# 3516                NaN           NaN              NaN         4.81  ...
# 3517                NaN           NaN              NaN         2.39  ...
# 3518                NaN           NaN              NaN         5.65  ...
# 3519                NaN           NaN              NaN         4.55  ...
#
#       ef_regulation_business_impartial  ef_regulation_business_compliance  \
# 0                                 4.93                               3.65
# 1                                 3.62                               2.95
# 2                                 2.90                               1.81
# 3                                 5.69                               2.42
# 4                                 3.60                               0.00
# ...                                ...                                ...
# 3515                              1.92                               0.00
# 3516                              3.88                               4.79
# 3517                              0.62                               6.11
# 3518                              4.39                               4.30
# 3519                              2.63                               4.89
#
#       ef_regulation_business  ef_regulation_enter_openness  \
# 0                       4.29                          5.76
# 1                       3.28                          3.94
# 2                       2.36                          0.56
# 3                       5.60                          5.65
# 4                       1.80                          5.17
# ...                      ...                           ...
# 3515                    0.80                          1.39
# 3516                    4.55                          4.55
# 3517                    2.42                          2.07
# 3518                    4.06                          2.44
# 3519                    3.15                          2.08
#
#       ef_regulation_enter_permits  ef_regulation_enter_distortion  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
# 3                             NaN                             NaN
# 4                             NaN                             NaN
# ...                           ...                             ...
# 3515                         4.98                            0.49
# 3516                         8.21                            3.96
# 3517                          NaN                            5.00
# 3518                         7.85                            0.19
# 3519                         7.99                            0.00
#
#       ef_regulation_enter  ef_regulation  ef_score  ef_rank
# 0                    5.76           5.69      6.48     71.0
# 1                    3.94           3.64      4.69    119.0
# 2                    0.56           4.13       NaN      NaN
# 3                    5.65           5.98      7.13     40.0
# 4                    5.17           4.50       NaN      NaN
# ...                   ...            ...       ...      ...
# 3515                 2.29           2.17      3.01    165.0
# 3516                 5.57           6.10      6.26    106.0
# 3517                 3.54           3.08      4.18    161.0
# 3518                 3.49           4.89      5.84    129.0
# 3519                 3.36           4.54      3.81    164.0
#
# [3520 rows x 145 columns]

# %%
def corr(groupped):
    return groupped [['HDI', 'HFI']].corr().iloc[0, 1]

# %%
by_year_corr = merge.groupby('Year').apply(corr)

# %%
by_year = by_year_corr.to_frame().reset_index()

# %%
by_year = by_year.rename(columns = {0 : 'Correlation'})
by_year
# Out:
#     Year  Correlation
# 0   2000     0.738530
# 1   2001     0.747798
# 2   2002     0.743742
# 3   2003     0.729451
# 4   2004     0.732868
# 5   2005     0.733759
# 6   2006     0.718856
# 7   2007     0.707296
# 8   2008     0.706415
# 9   2009     0.700434
# 10  2010     0.657310
# 11  2011     0.630806
# 12  2012     0.631851
# 13  2013     0.633953
# 14  2014     0.629854
# 15  2015     0.619561
# 16  2016     0.626163
# 17  2017     0.627618
# 18  2018     0.624300
# 19  2019     0.636878
# 20  2020     0.641568
# 21  2021     0.638828

# %%
##by_year.to_csv('corr_by_year_hdi_hfi.csv', index = False)
