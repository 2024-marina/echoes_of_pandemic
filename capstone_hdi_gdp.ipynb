# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
hdi_excel = pd.read_excel('../data/capstone_hdr_2023_24.xlsx')

# %%
hdi_excel.to_csv ("capstone_hdr_2023_24_2.csv", index = None, header=True)

# %%
hdi = pd.read_csv('../data/capstone_hdr_2023_24_2.csv', skiprows = 4, nrows = 197)

# %%
hdi.columns
# Out:
# Index(['HDI rank', 'Country', '1990', 'Unnamed: 3', '2000', 'Unnamed: 5',
#        '2010', 'Unnamed: 7', '2015', 'Unnamed: 9', '2019', 'Unnamed: 11',
#        '2020', 'Unnamed: 13', '2021', 'Unnamed: 15', '2022', 'Unnamed: 17',
#        '2015-2022', 'a', '1990-2000', 'Unnamed: 21', '2000-2010',
#        'Unnamed: 23', '2010-2022', 'Unnamed: 25', '1990-2022'],
#       dtype='object')

# %%
col_delete = ['Unnamed: 3', 'Unnamed: 5', 'Unnamed: 7', 'Unnamed: 9', 'Unnamed: 11', 'Unnamed: 13', 'Unnamed: 15', 'Unnamed: 17', 'a', 'Unnamed: 21', 'Unnamed: 23', 'Unnamed: 25']

# %%
hdi = hdi.drop(columns = col_delete)

# %%
hdi.head()
# Out:
#    HDI rank                      Country   1990   2000   2010   2015   2019  \
# 0       NaN  VERY HIGH HUMAN DEVELOPMENT    NaN    NaN    NaN    NaN    NaN
# 1       1.0                  Switzerland   0.85  0.885   0.94  0.952   0.96
# 2       2.0                       Norway  0.845  0.914  0.938  0.952  0.961
# 3       3.0                      Iceland  0.834  0.895  0.927  0.948  0.958
# 4       4.0       Hong Kong, China (SAR)  0.739  0.831  0.914  0.936  0.953
#
#     2020   2021   2022 2015-2022            1990-2000            2000-2010  \
# 0    NaN    NaN    NaN       NaN                  NaN                  NaN
# 1  0.957  0.965  0.967         0  0.40432816488427115    0.604743537446506
# 2  0.963  0.964  0.966        -1   0.7880281668532385  0.25952997299196756
# 3  0.955  0.957  0.959         0   0.7084005283893413   0.3519162491963934
# 4  0.955  0.959  0.956         2   1.1802291238897533   0.9565537745857444
#
#             2010-2022           1990-2022
# ...

# %%
hdi = hdi.dropna(subset=['HDI rank'])

# %%
hdi.columns
# Out:
# Index(['HDI rank', 'Country', '1990', '2000', '2010', '2015', '2019', '2020',
#        '2021', '2022', '2015-2022', '1990-2000', '2000-2010', '2010-2022',
#        '1990-2022'],
#       dtype='object')

# %%
## hdi.to_csv('hdi_cleaned.csv', index = True)

# %%
hdi
# Out:
#      HDI rank                   Country   1990   2000   2010   2015   2019  \
# 1         1.0               Switzerland   0.85  0.885   0.94  0.952   0.96
# 2         2.0                    Norway  0.845  0.914  0.938  0.952  0.961
# 3         3.0                   Iceland  0.834  0.895  0.927  0.948  0.958
# 4         4.0    Hong Kong, China (SAR)  0.739  0.831  0.914  0.936  0.953
# 5         5.0                   Denmark  0.839   0.89  0.913  0.936  0.946
# ..        ...                       ...    ...    ...    ...    ...    ...
# 192     189.0                      Chad     ..  0.292  0.364  0.388  0.398
# 193     189.0                     Niger  0.212   0.26  0.336  0.367   0.39
# 194     191.0  Central African Republic  0.333  0.319  0.357  0.367  0.391
# 195     192.0               South Sudan     ..     ..  0.406  0.381  0.391
# 196     193.0                   Somalia     ..     ..     ..     ..     ..
#
# ...

# %%
##world_by_year = ['average_1990-2015', '2019', '2020', '2021', '2022']

# %%
gdp = pd.read_csv('../data/gdp.csv', nrows = 217)

# %%
gdp.columns
# Out:
# Index(['Series Name', 'Series Code', 'Country Name', 'Country Code',
#        '2000 [YR2000]', '2001 [YR2001]', '2002 [YR2002]', '2003 [YR2003]',
#        '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]', '2007 [YR2007]',
#        '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]',
#        '2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]', '2021 [YR2021]',
#        '2022 [YR2022]', '2023 [YR2023]'],
#       dtype='object')

# %%
col_delete2 = ['Series Name', 'Series Code']
gdp = gdp.drop(columns = col_delete2)

# %%
gdp.columns = gdp.columns.str.replace(r'\[YR\d+\]', '', regex = True)

# %%
gdp_world = pd.read_csv('../data/gdp.csv', skiprows = range (1, 266), nrows = 1)
gdp_world
# Out:
#                         Series Name        Series Code Country Name  \
# 0  GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG        World
#
#   Country Code  2000 [YR2000]  2001 [YR2001]  2002 [YR2002]  2003 [YR2003]  \
# 0          WLD       3.135588        0.68108        0.97631       1.792262
#
#    2004 [YR2004]  2005 [YR2005]  ...  2014 [YR2014]  2015 [YR2015]  \
# 0       3.154465       2.708275  ...       1.885841       1.915147
#
#    2016 [YR2016]  2017 [YR2017]  2018 [YR2018]  2019 [YR2019]  2020 [YR2020]  \
# 0       1.630446       2.283867       2.153227       1.561181      -3.906872
#
#    2021 [YR2021]  2022 [YR2022]  2023 [YR2023]
# 0       5.348079       2.277611       1.779799
#
# [1 rows x 22 columns]

# %%
gdp_world.columns = gdp_world.columns.str.replace(r'\[YR\d+\]', '', regex = True)

# %%
col_delete2 = ['Series Name', 'Series Code']
gdp_world = gdp_world.drop(columns = col_delete2)

# %%
gdp_world
# Out:
#   Country Name Country Code     2000     2001     2002      2003      2004   \
# 0        World          WLD  3.135588  0.68108  0.97631  1.792262  3.154465
#
#       2005      2006      2007      2014      2015      2016      2017   \
# 0  2.708275  3.146138  3.092674  1.885841  1.915147  1.630446  2.283867
#
#       2018      2019      2020      2021      2022      2023
# 0  2.153227  1.561181 -3.906872  5.348079  2.277611  1.779799

# %%
row = gdp_world[gdp_world['Country Name'] == 'World'].drop(columns = ['Country Name', 'Country Code'])

# %%
row = row.astype(float)

# %%
years = row.columns

# %%
values = row.values[0]

# %%
plt.figure (figsize = (12, 6))
plt.plot(years, values, marker = 'o')
plt.grid(True)
plt.ylim(bottom = -5, top = 8)
plt.show();

# %%
combined_gdp = pd.concat([gdp, gdp_world])

# %%
combined_gdp.reset_index(drop = True, inplace = True)

# %%
combined_gdp
# Out:
#            Country Name Country Code         2000          2001   \
# 0           Afghanistan          AFG            ..  -10.10196643
# 1               Albania          ALB   7.630022439   9.314397139
# 2               Algeria          DZA   2.354580271   1.592496614
# 3        American Samoa          ASM            ..            ..
# 4               Andorra          AND    2.83605354   5.372532989
# ..                  ...          ...           ...           ...
# 213  West Bank and Gaza          PSE  -10.86318811  -11.59863728
# 214         Yemen, Rep.          YEM   3.251318206   1.012423088
# 215              Zambia          ZMB   1.062291692   2.208315021
# 216            Zimbabwe          ZWE  -4.027575911   0.789790878
# 217               World          WLD      3.135588       0.68108
#
#             2002          2003          2004          2005          2006   \
# 0     20.56796346   0.927029119  -2.497254626   7.321873845   1.084988197
# ...

# %%
##combined_gdp.to_csv('combined_gdp.csv', index = True)

# %%
world = hdi.drop(columns = ['HDI rank', 'Country'])

# %%
hdi_world = pd.read_csv('../data/capstone_hdr_2023_24_2.csv', skiprows = 4, nrows = 223)

# %%
hdi_world.tail()
# Out:
#      HDI rank                                            Country   1990  \
# 218       NaN                     Small island developing states  0.605
# 219       NaN                                                NaN    NaN
# 220       NaN  Organisation for Economic Co-operation and Dev...  0.796
# 221       NaN                                                NaN    NaN
# 222       NaN                                              World  0.601
#
#     Unnamed: 3   2000  Unnamed: 5   2010  Unnamed: 7   2015  Unnamed: 9  ...  \
# 218        NaN   0.65         NaN  0.694         NaN  0.721         NaN  ...
# 219        NaN    NaN         NaN    NaN         NaN    NaN         NaN  ...
# 220        NaN  0.842         NaN  0.878         NaN  0.894         NaN  ...
# 221        NaN    NaN         NaN    NaN         NaN    NaN         NaN  ...
# 222        NaN  0.645         NaN  0.698         NaN  0.724         NaN  ...
#
#     Unnamed: 17  2015-2022   a           1990-2000 Unnamed: 21  \
# ...

# %%
hdi_world.columns
# Out:
# Index(['HDI rank', 'Country', '1990', 'Unnamed: 3', '2000', 'Unnamed: 5',
#        '2010', 'Unnamed: 7', '2015', 'Unnamed: 9', '2019', 'Unnamed: 11',
#        '2020', 'Unnamed: 13', '2021', 'Unnamed: 15', '2022', 'Unnamed: 17',
#        '2015-2022', 'a', '1990-2000', 'Unnamed: 21', '2000-2010',
#        'Unnamed: 23', '2010-2022', 'Unnamed: 25', '1990-2022'],
#       dtype='object')

# %%
col_delete2 = ['Unnamed: 3', 'Unnamed: 5', 'Unnamed: 7', 'Unnamed: 9', 'Unnamed: 11', 'Unnamed: 13', 'Unnamed: 15', 'Unnamed: 17', 'a', 'Unnamed: 21', 'Unnamed: 23', 'Unnamed: 25']
hdi_world = hdi_world.drop(columns = col_delete2)

# %%
hdi_world.tail()
# Out:
#      HDI rank                                            Country   1990  \
# 218       NaN                     Small island developing states  0.605
# 219       NaN                                                NaN    NaN
# 220       NaN  Organisation for Economic Co-operation and Dev...  0.796
# 221       NaN                                                NaN    NaN
# 222       NaN                                              World  0.601
#
#       2000   2010   2015   2019   2020   2021   2022 2015-2022  \
# 218   0.65  0.694  0.721  0.731  0.727  0.722   0.73         —
# 219    NaN    NaN    NaN    NaN    NaN    NaN    NaN       NaN
# 220  0.842  0.878  0.894  0.905  0.897  0.899  0.906         —
# 221    NaN    NaN    NaN    NaN    NaN    NaN    NaN       NaN
# 222  0.645  0.698  0.724  0.739  0.736  0.735  0.739         —
#
#               1990-2000           2000-2010            2010-2022  \
# 218  0.7200188082414183  0.6571457659309665   0.4223274128915211
# ...

# %%
hdi_world = hdi_world[hdi_world['Country'] == 'World']
hdi_world.reset_index()
# Out:
#    index  HDI rank Country   1990   2000   2010   2015   2019   2020   2021  \
# 0    222       NaN   World  0.601  0.645  0.698  0.724  0.739  0.736  0.735
#
#     2022 2015-2022           1990-2000          2000-2010  \
# 0  0.739         —  0.7090558032690097  0.792814118053875
#
#              2010-2022           1990-2022
# 0  0.47678986101160614  0.6480375683492801

# %%
combined_hdi = pd.concat([hdi, hdi_world])

# %%
combined_hdi.reset_index()
# Out:
#      index  HDI rank                   Country   1990   2000   2010   2015  \
# 0        1       1.0               Switzerland   0.85  0.885   0.94  0.952
# 1        2       2.0                    Norway  0.845  0.914  0.938  0.952
# 2        3       3.0                   Iceland  0.834  0.895  0.927  0.948
# 3        4       4.0    Hong Kong, China (SAR)  0.739  0.831  0.914  0.936
# 4        5       5.0                   Denmark  0.839   0.89  0.913  0.936
# ..     ...       ...                       ...    ...    ...    ...    ...
# 189    193     189.0                     Niger  0.212   0.26  0.336  0.367
# 190    194     191.0  Central African Republic  0.333  0.319  0.357  0.367
# 191    195     192.0               South Sudan     ..     ..  0.406  0.381
# 192    196     193.0                   Somalia     ..     ..     ..     ..
# 193    222       NaN                     World  0.601  0.645  0.698  0.724
#
#       2019   2020   2021   2022 2015-2022             1990-2000  \
# ...

# %%
##combined_hdi.to_csv('combined_hdi.csv', index = True)

# %%
combined_hdi.columns
# Out:
# Index(['HDI rank', 'Country', '1990', '2000', '2010', '2015', '2019', '2020',
#        '2021', '2022', '2015-2022', '1990-2000', '2000-2010', '2010-2022',
#        '1990-2022'],
#       dtype='object')

# %%
years = ['1990', '2000', '2010', '2015', '2019', '2020','2021', '2022']

# %%
unpivot = combined_hdi.melt(id_vars = ['HDI rank', 'Country'], value_vars = years, var_name = 'Year', value_name = 'HDI')

# %%
unpivot['HDI rank'] = unpivot['HDI rank'].fillna(000).astype(int)

# %%
## unpivot.to_csv('for_powerBI.csv', index = False)

# %%
years = ['2000 ', '2001 ', '2002 ', '2003 ', '2004 ', '2005 ', '2006 ', '2007 ', '2014 ', '2015 ', '2016 ', '2017 ', '2018 ', '2019 ', '2020 ', '2021 ', '2022 ', '2023 ']

# %%
unpivot2 = combined_gdp.melt(id_vars = ['Country Name'], value_vars = years, var_name = 'Year', value_name = 'GDP change, pct')

# %%
combined_gdp.columns
# Out:
# Index(['Country Name', 'Country Code', '2000 ', '2001 ', '2002 ', '2003 ',
#        '2004 ', '2005 ', '2006 ', '2007 ', '2014 ', '2015 ', '2016 ', '2017 ',
#        '2018 ', '2019 ', '2020 ', '2021 ', '2022 ', '2023 '],
#       dtype='object')

# %%
combined_gdp
# Out:
#            Country Name Country Code         2000          2001   \
# 0           Afghanistan          AFG            ..  -10.10196643
# 1               Albania          ALB   7.630022439   9.314397139
# 2               Algeria          DZA   2.354580271   1.592496614
# 3        American Samoa          ASM            ..            ..
# 4               Andorra          AND    2.83605354   5.372532989
# ..                  ...          ...           ...           ...
# 213  West Bank and Gaza          PSE  -10.86318811  -11.59863728
# 214         Yemen, Rep.          YEM   3.251318206   1.012423088
# 215              Zambia          ZMB   1.062291692   2.208315021
# 216            Zimbabwe          ZWE  -4.027575911   0.789790878
# 217               World          WLD      3.135588       0.68108
#
#             2002          2003          2004          2005          2006   \
# 0     20.56796346   0.927029119  -2.497254626   7.321873845   1.084988197
# ...

# %%
unpivot2
# Out:
#             Country Name   Year GDP change, pct
# 0            Afghanistan  2000               ..
# 1                Albania  2000      7.630022439
# 2                Algeria  2000      2.354580271
# 3         American Samoa  2000               ..
# 4                Andorra  2000       2.83605354
# ...                  ...    ...             ...
# 3919  West Bank and Gaza  2023     -7.743372756
# 3920         Yemen, Rep.  2023               ..
# 3921              Zambia  2023      2.992083549
# 3922            Zimbabwe  2023      2.783839188
# 3923               World  2023         1.779799
#
# [3924 rows x 3 columns]

# %%
##unpivot2.to_csv('for_powerBI_gdp.csv', index = False)

# %%
gdp_rate = pd.read_csv('../data/gdp_growth_2000-23_py.csv', skiprows = 3, nrows = 223)

# %%
gdp_rate = gdp_rate.rename(columns = {'Country Name' : 'Country'})

# %%
gdp_rate.columns
# Out:
# Index(['Country', 'Country Code', 'Indicator Name', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020',
#        '2021', '2022', '2023'],
#       dtype='object')

# %%
years = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
       '2016', '2017', '2018', '2019', '2020', '2021', '2022']

# %%
unpivot5 = pd.melt(gdp_rate, id_vars = ['Country'], var_name = 'Year', value_name = 'GDP_pct')
unpivot5
# Out:
#           Country          Year   GDP_pct
# 0           Aruba  Country Code       ABW
# 1     Afghanistan  Country Code       AFG
# 2          Angola  Country Code       AGO
# 3         Albania  Country Code       ALB
# 4         Andorra  Country Code       AND
# ...           ...           ...       ...
# 5793        Samoa          2023  6.413358
# 5794       Kosovo          2023  4.026981
# 5795  Yemen, Rep.          2023       NaN
# 5796       Zambia          2023  2.992084
# 5797     Zimbabwe          2023  2.783839
#
# [5798 rows x 3 columns]

# %%
##unpivot5.to_csv('gdp_long_2000_2022.csv', index = False)
